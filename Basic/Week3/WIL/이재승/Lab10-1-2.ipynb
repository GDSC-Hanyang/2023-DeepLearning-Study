# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist
from time import time
import os

# %%
def load(model, checkpoint_dir):
    print(" [*] Reading checkpoints...")

    ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
    if ckpt :
        ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
        checkpoint = tf.train.Checkpoint(dnn=model)
        checkpoint.restore(save_path=os.path.join(checkpoint_dir, ckpt_name))
        counter = int(ckpt_name.split('-')[1])
        print(" [*] Success to read {}".format(ckpt_name))
        return True, counter
    else:
        print(" [*] Failed to find a checkpoint")
        return False, 0

def check_folder(dir):
    if not os.path.exists(dir):
        os.makedirs(dir)
    return dir

# %%
def load_mnist() :
    (train_data, train_labels), (test_data, test_labels) = mnist.load_data()
    # channel을 하나 추가하는 이유 :
    #   tensorflow가 받는 input의 경우 4개인데, 우리 input은 마지막 변수가 없어 추가
    #   -1 : 마지막을 의미.
    train_data = np.expand_dims(train_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]
    test_data = np.expand_dims(test_data, axis=-1) # [N, 28, 28] -> [N, 28, 28, 1]

    train_data, test_data = normalize(train_data, test_data)

    # One hot encoding (label의 갯수에 맞게 to_categorical 사용)
    train_labels = to_categorical(train_labels, 10) # [N,] -> [N, 10]
    test_labels = to_categorical(test_labels, 10) # [N,] -> [N, 10]

    return train_data, train_labels, test_data, test_labels

def normalize(train_data, test_data):
    train_data = train_data.astype(np.float32) / 255.0
    test_data = test_data.astype(np.float32) / 255.0

    return train_data, test_data

# %%
def flatten() :
    # shape을 펼쳐줌
    return tf.keras.layers.Flatten()

def dense(label_dim, weight_init) :
    # fully connected layer 사용시 선언. kernel_initializer : weight init
    return tf.keras.layers.Dense(units=label_dim, use_bias=True, kernel_initializer=weight_init)

def relu() :
    return tf.keras.layers.Activation(tf.keras.activations.relu)

# %%
class create_model_class(tf.keras.Model):
    # class type으로 모델을 만들 시 tf.keras.Model 상속 필요
    def __init__(self, label_dim):
        super(create_model_class, self).__init__()
        weight_init = tf.keras.initializers.RandomNormal()

        self.model = tf.keras.Sequential() # 리스트 자료구조 타입
        self.model.add(flatten()) # [N, 28, 28, 1] -> [N, 784]로 바꿈. FC 사용위함.

        for i in range(2):
            self.model.add(dense(256, weight_init))
            self.model.add(relu())

        self.model.add(dense(label_dim, weight_init))

    def call(self, x, training=None, mask=None):
        x = self.model(x)

        return x

# %%
# 위 클래스의 function ver
def create_model_function(label_dim) :
    weight_init = tf.keras.initializers.RandomNormal()

    model = tf.keras.Sequential()
    model.add(flatten())

    for i in range(2) :
        model.add(dense(256, weight_init))
        model.add(relu())

    model.add(dense(label_dim, weight_init))

    return model

# %%
def loss_fn(model, images, labels):
    logits = model(images, training=True)
    loss = tf.reduce_mean(tf.keras.losses.categorical_crossentropy(y_pred=logits, y_true=labels,
                                                                   from_logits=True))
    return loss

def accuracy_fn(model, images, labels):
    logits = model(images, training=False)
    # argxmax : logit과 label에서 가장 큰 값을 갖고 있는 곳의 위치를 구함.
    prediction = tf.equal(tf.argmax(logits, -1), tf.argmax(labels, -1))
    accuracy = tf.reduce_mean(tf.cast(prediction, tf.float32))
    return accuracy

def grad(model, images, labels):
    with tf.GradientTape() as tape:
        loss = loss_fn(model, images, labels)
    return tape.gradient(loss, model.variables)

# %%
""" dataset """
train_x, train_y, test_x, test_y = load_mnist()

""" parameters """
learning_rate = 0.001
batch_size = 128

training_epochs = 1
training_iterations = len(train_x) // batch_size

label_dim = 10

train_flag = True

""" Graph Input using Dataset API """
# shuffle(). 데이터셋 섞기 (주어진 input보다 큰 숫자를 넣어야 함)
# prefetch() 더 빠르게 학습하기 위해 batch size만큼 미리 메모리를 점유해놓는 것
train_dataset = tf.data.Dataset.from_tensor_slices((train_x, train_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=batch_size).\
    batch(batch_size, drop_remainder=True)

test_dataset = tf.data.Dataset.from_tensor_slices((test_x, test_y)).\
    shuffle(buffer_size=100000).\
    prefetch(buffer_size=len(test_x)).\
    batch(len(test_x))

# %%
""" Model """
network = create_model_function(label_dim)

""" Training """
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

""" Writer """
checkpoint_dir = 'checkpoints'
logs_dir = 'logs'

model_dir = 'nn_relu'

checkpoint_dir = os.path.join(checkpoint_dir, model_dir)
check_folder(checkpoint_dir)
checkpoint_prefix = os.path.join(checkpoint_dir, model_dir)
logs_dir = os.path.join(logs_dir, model_dir)

# %%
if train_flag :

    checkpoint = tf.train.Checkpoint(dnn=network)

    # create writer for tensorboard
    summary_writer = tf.summary.create_file_writer(logdir=logs_dir)
    start_time = time()

    # restore check-point if it exits
    could_load, checkpoint_counter = load(network, checkpoint_dir)

    if could_load:
        start_epoch = (int)(checkpoint_counter / training_iterations)
        counter = checkpoint_counter
        print(" [*] Load SUCCESS")
    else:
        start_epoch = 0
        start_iteration = 0
        counter = 0
        print(" [!] Load failed...")

    # train phase
    with summary_writer.as_default():  # for tensorboard
        for epoch in range(start_epoch, training_epochs):
            for idx, (train_input, train_label) in enumerate(train_dataset):
                grads = grad(network, train_input, train_label)
                optimizer.apply_gradients(grads_and_vars=zip(grads, network.variables))

                train_loss = loss_fn(network, train_input, train_label)
                train_accuracy = accuracy_fn(network, train_input, train_label)

                for test_input, test_label in test_dataset:
                    test_accuracy = accuracy_fn(network, test_input, test_label)

                tf.summary.scalar(name='train_loss', data=train_loss, step=counter)
                tf.summary.scalar(name='train_accuracy', data=train_accuracy, step=counter)
                tf.summary.scalar(name='test_accuracy', data=test_accuracy, step=counter)

                print(
                    "Epoch: [%2d] [%5d/%5d] time: %4.4f, train_loss: %.8f, train_accuracy: %.4f, test_Accuracy: %.4f" \
                    % (epoch, idx, training_iterations, time() - start_time, train_loss, train_accuracy,
                       test_accuracy))
                counter += 1
        checkpoint.save(file_prefix=checkpoint_prefix + '-{}'.format(counter))

# test phase
else :
    _, _ = load(network, checkpoint_dir)
    for test_input, test_label in test_dataset:
        test_accuracy = accuracy_fn(network, test_input, test_label)

    print("test_Accuracy: %.4f" % (test_accuracy))
# Out:
#  [*] Reading checkpoints...
#  [*] Failed to find a checkpoint
#  [!] Load failed...
# Epoch: [ 0] [    0/  468] time: 0.5870, train_loss: 2.17735147, train_accuracy: 0.1719, test_Accuracy: 0.1182
# Epoch: [ 0] [    1/  468] time: 0.8221, train_loss: 2.13722348, train_accuracy: 0.2188, test_Accuracy: 0.1898
# Epoch: [ 0] [    2/  468] time: 1.0634, train_loss: 2.07351685, train_accuracy: 0.4062, test_Accuracy: 0.3921
# Epoch: [ 0] [    3/  468] time: 1.2899, train_loss: 2.00702357, train_accuracy: 0.6016, test_Accuracy: 0.5858
# Epoch: [ 0] [    4/  468] time: 1.6380, train_loss: 1.95712912, train_accuracy: 0.5859, test_Accuracy: 0.6273
# Epoch: [ 0] [    5/  468] time: 1.9908, train_loss: 1.83389163, train_accuracy: 0.6641, test_Accuracy: 0.6479
# Epoch: [ 0] [    6/  468] time: 2.2047, train_loss: 1.68618131, train_accuracy: 0.7109, test_Accuracy: 0.6635
# Epoch: [ 0] [    7/  468] time: 2.4364, train_loss: 1.65125406, train_accuracy: 0.6797, test_Accuracy: 0.6809
# Epoch: [ 0] [    8/  468] time: 2.6746, train_loss: 1.59677291, train_accuracy: 0.6328, test_Accuracy: 0.7142
# Epoch: [ 0] [    9/  468] time: 3.0250, train_loss: 1.39052415, train_accuracy: 0.7656, test_Accuracy: 0.7439
# Epoch: [ 0] [   10/  468] time: 3.2507, train_loss: 1.25736332, train_accuracy: 0.7812, test_Accuracy: 0.7682
# Epoch: [ 0] [   11/  468] time: 3.6039, train_loss: 1.23215020, train_accuracy: 0.7656, test_Accuracy: 0.7892
# Epoch: [ 0] [   12/  468] time: 3.8465, train_loss: 1.16011894, train_accuracy: 0.8047, test_Accuracy: 0.8076
# Epoch: [ 0] [   13/  468] time: 4.0705, train_loss: 1.00934339, train_accuracy: 0.7969, test_Accuracy: 0.8116
# Epoch: [ 0] [   14/  468] time: 4.3056, train_loss: 1.00755978, train_accuracy: 0.7969, test_Accuracy: 0.8112
# Epoch: [ 0] [   15/  468] time: 4.5488, train_loss: 1.00102806, train_accuracy: 0.7578, test_Accuracy: 0.8262
# Epoch: [ 0] [   16/  468] time: 4.8986, train_loss: 0.81829906, train_accuracy: 0.8125, test_Accuracy: 0.8317
# Epoch: [ 0] [   17/  468] time: 5.1287, train_loss: 0.74665606, train_accuracy: 0.8594, test_Accuracy: 0.8225
# Epoch: [ 0] [   18/  468] time: 5.3489, train_loss: 0.70969594, train_accuracy: 0.8594, test_Accuracy: 0.8268
# Epoch: [ 0] [   19/  468] time: 5.5818, train_loss: 0.63087320, train_accuracy: 0.8359, test_Accuracy: 0.8420
# Epoch: [ 0] [   20/  468] time: 5.8090, train_loss: 0.63991296, train_accuracy: 0.8281, test_Accuracy: 0.8498
# Epoch: [ 0] [   21/  468] time: 6.1594, train_loss: 0.54806834, train_accuracy: 0.8438, test_Accuracy: 0.8441
# Epoch: [ 0] [   22/  468] time: 6.3678, train_loss: 0.54171830, train_accuracy: 0.8672, test_Accuracy: 0.8381
# Epoch: [ 0] [   23/  468] time: 6.5979, train_loss: 0.51150095, train_accuracy: 0.8516, test_Accuracy: 0.8382
# Epoch: [ 0] [   24/  468] time: 6.8356, train_loss: 0.42700297, train_accuracy: 0.8828, test_Accuracy: 0.8401
# Epoch: [ 0] [   25/  468] time: 7.0738, train_loss: 0.40832239, train_accuracy: 0.8750, test_Accuracy: 0.8437
# Epoch: [ 0] [   26/  468] time: 7.3057, train_loss: 0.59730452, train_accuracy: 0.7969, test_Accuracy: 0.8507
# Epoch: [ 0] [   27/  468] time: 7.5419, train_loss: 0.53605199, train_accuracy: 0.8438, test_Accuracy: 0.8557
# Epoch: [ 0] [   28/  468] time: 7.7803, train_loss: 0.51569057, train_accuracy: 0.8672, test_Accuracy: 0.8611
# Epoch: [ 0] [   29/  468] time: 8.1281, train_loss: 0.60690242, train_accuracy: 0.8047, test_Accuracy: 0.8552
# Epoch: [ 0] [   30/  468] time: 8.4753, train_loss: 0.60420120, train_accuracy: 0.8047, test_Accuracy: 0.8609
# Epoch: [ 0] [   31/  468] time: 8.7097, train_loss: 0.50088573, train_accuracy: 0.8516, test_Accuracy: 0.8679
# Epoch: [ 0] [   32/  468] time: 8.9353, train_loss: 0.45396602, train_accuracy: 0.8906, test_Accuracy: 0.8705
# Epoch: [ 0] [   33/  468] time: 9.1495, train_loss: 0.37769067, train_accuracy: 0.8906, test_Accuracy: 0.8769
# Epoch: [ 0] [   34/  468] time: 9.3677, train_loss: 0.34968233, train_accuracy: 0.9062, test_Accuracy: 0.8783
# Epoch: [ 0] [   35/  468] time: 9.6006, train_loss: 0.41140240, train_accuracy: 0.8594, test_Accuracy: 0.8754
# Epoch: [ 0] [   36/  468] time: 9.8323, train_loss: 0.46857601, train_accuracy: 0.8438, test_Accuracy: 0.8709
# Epoch: [ 0] [   37/  468] time: 10.0585, train_loss: 0.48907337, train_accuracy: 0.8359, test_Accuracy: 0.8650
# Epoch: [ 0] [   38/  468] time: 10.4192, train_loss: 0.49698633, train_accuracy: 0.8438, test_Accuracy: 0.8625
# Epoch: [ 0] [   39/  468] time: 11.1120, train_loss: 0.35862893, train_accuracy: 0.8828, test_Accuracy: 0.8740
# Epoch: [ 0] [   40/  468] time: 11.4783, train_loss: 0.37814760, train_accuracy: 0.8984, test_Accuracy: 0.8879
# Epoch: [ 0] [   41/  468] time: 11.8213, train_loss: 0.35691160, train_accuracy: 0.8906, test_Accuracy: 0.8816
# Epoch: [ 0] [   42/  468] time: 12.1912, train_loss: 0.43898386, train_accuracy: 0.8594, test_Accuracy: 0.8655
# Epoch: [ 0] [   43/  468] time: 12.5641, train_loss: 0.29318437, train_accuracy: 0.9375, test_Accuracy: 0.8540
# Epoch: [ 0] [   44/  468] time: 12.8092, train_loss: 0.34573296, train_accuracy: 0.8984, test_Accuracy: 0.8659
# Epoch: [ 0] [   45/  468] time: 13.0194, train_loss: 0.33665866, train_accuracy: 0.8984, test_Accuracy: 0.8802
# Epoch: [ 0] [   46/  468] time: 13.3673, train_loss: 0.21767479, train_accuracy: 0.9297, test_Accuracy: 0.8895
# Epoch: [ 0] [   47/  468] time: 13.6053, train_loss: 0.39234096, train_accuracy: 0.8750, test_Accuracy: 0.8826
# Epoch: [ 0] [   48/  468] time: 13.9638, train_loss: 0.31876367, train_accuracy: 0.9141, test_Accuracy: 0.8742
# Epoch: [ 0] [   49/  468] time: 14.3145, train_loss: 0.38307041, train_accuracy: 0.8359, test_Accuracy: 0.8760
# Epoch: [ 0] [   50/  468] time: 14.5100, train_loss: 0.59813738, train_accuracy: 0.8359, test_Accuracy: 0.8837
# Epoch: [ 0] [   51/  468] time: 14.7362, train_loss: 0.34643877, train_accuracy: 0.9141, test_Accuracy: 0.8905
# Epoch: [ 0] [   52/  468] time: 14.9534, train_loss: 0.36051497, train_accuracy: 0.9062, test_Accuracy: 0.8937
# Epoch: [ 0] [   53/  468] time: 15.3024, train_loss: 0.23696937, train_accuracy: 0.9141, test_Accuracy: 0.8929
# Epoch: [ 0] [   54/  468] time: 15.5216, train_loss: 0.44806680, train_accuracy: 0.8828, test_Accuracy: 0.8873
# Epoch: [ 0] [   55/  468] time: 15.7512, train_loss: 0.48584482, train_accuracy: 0.8828, test_Accuracy: 0.8865
# Epoch: [ 0] [   56/  468] time: 15.9906, train_loss: 0.40566307, train_accuracy: 0.8672, test_Accuracy: 0.8890
# Epoch: [ 0] [   57/  468] time: 16.2312, train_loss: 0.34512854, train_accuracy: 0.8906, test_Accuracy: 0.8984
# Epoch: [ 0] [   58/  468] time: 16.4596, train_loss: 0.29693311, train_accuracy: 0.8828, test_Accuracy: 0.9052
# Epoch: [ 0] [   59/  468] time: 16.8084, train_loss: 0.29613662, train_accuracy: 0.9062, test_Accuracy: 0.9032
# Epoch: [ 0] [   60/  468] time: 17.0580, train_loss: 0.27549398, train_accuracy: 0.9297, test_Accuracy: 0.8960
# Epoch: [ 0] [   61/  468] time: 17.4076, train_loss: 0.35012653, train_accuracy: 0.9219, test_Accuracy: 0.8951
# Epoch: [ 0] [   62/  468] time: 17.6451, train_loss: 0.33269560, train_accuracy: 0.9141, test_Accuracy: 0.8930
# Epoch: [ 0] [   63/  468] time: 17.8922, train_loss: 0.33124244, train_accuracy: 0.9062, test_Accuracy: 0.8925
# Epoch: [ 0] [   64/  468] time: 18.1098, train_loss: 0.42976087, train_accuracy: 0.8906, test_Accuracy: 0.8986
# Epoch: [ 0] [   65/  468] time: 18.3106, train_loss: 0.25164843, train_accuracy: 0.9297, test_Accuracy: 0.9021
# Epoch: [ 0] [   66/  468] time: 18.5449, train_loss: 0.34238225, train_accuracy: 0.8906, test_Accuracy: 0.9041
# Epoch: [ 0] [   67/  468] time: 18.7831, train_loss: 0.23956662, train_accuracy: 0.9297, test_Accuracy: 0.9035
# Epoch: [ 0] [   68/  468] time: 19.0206, train_loss: 0.31862423, train_accuracy: 0.9141, test_Accuracy: 0.9045
# Epoch: [ 0] [   69/  468] time: 19.2568, train_loss: 0.25042740, train_accuracy: 0.9453, test_Accuracy: 0.9025
# Epoch: [ 0] [   70/  468] time: 19.4818, train_loss: 0.29590893, train_accuracy: 0.9375, test_Accuracy: 0.8980
# Epoch: [ 0] [   71/  468] time: 19.7096, train_loss: 0.34009400, train_accuracy: 0.8906, test_Accuracy: 0.8953
# Epoch: [ 0] [   72/  468] time: 19.9381, train_loss: 0.33511186, train_accuracy: 0.9219, test_Accuracy: 0.8953
# Epoch: [ 0] [   73/  468] time: 20.1821, train_loss: 0.43346384, train_accuracy: 0.8828, test_Accuracy: 0.8993
# Epoch: [ 0] [   74/  468] time: 20.5323, train_loss: 0.46332142, train_accuracy: 0.8750, test_Accuracy: 0.9035
# Epoch: [ 0] [   75/  468] time: 20.7666, train_loss: 0.28630173, train_accuracy: 0.8906, test_Accuracy: 0.9072
# Epoch: [ 0] [   76/  468] time: 21.0006, train_loss: 0.31986427, train_accuracy: 0.8906, test_Accuracy: 0.9073
# Epoch: [ 0] [   77/  468] time: 21.2333, train_loss: 0.31405821, train_accuracy: 0.9062, test_Accuracy: 0.9028
# Epoch: [ 0] [   78/  468] time: 21.4712, train_loss: 0.37385190, train_accuracy: 0.9141, test_Accuracy: 0.8996
# Epoch: [ 0] [   79/  468] time: 21.7126, train_loss: 0.37052888, train_accuracy: 0.8750, test_Accuracy: 0.9003
# Epoch: [ 0] [   80/  468] time: 21.9468, train_loss: 0.24749403, train_accuracy: 0.9297, test_Accuracy: 0.9022
# Epoch: [ 0] [   81/  468] time: 22.1820, train_loss: 0.29024684, train_accuracy: 0.9297, test_Accuracy: 0.9044
# Epoch: [ 0] [   82/  468] time: 22.5296, train_loss: 0.40744826, train_accuracy: 0.8984, test_Accuracy: 0.9097
# Epoch: [ 0] [   83/  468] time: 22.8822, train_loss: 0.41164699, train_accuracy: 0.8828, test_Accuracy: 0.9106
# Epoch: [ 0] [   84/  468] time: 23.2653, train_loss: 0.42462921, train_accuracy: 0.8828, test_Accuracy: 0.9101
# Epoch: [ 0] [   85/  468] time: 23.6375, train_loss: 0.31982887, train_accuracy: 0.9062, test_Accuracy: 0.9094
# Epoch: [ 0] [   86/  468] time: 24.0081, train_loss: 0.30409497, train_accuracy: 0.8906, test_Accuracy: 0.9080
# Epoch: [ 0] [   87/  468] time: 24.6982, train_loss: 0.22954145, train_accuracy: 0.9219, test_Accuracy: 0.9060
# Epoch: [ 0] [   88/  468] time: 25.0825, train_loss: 0.27824327, train_accuracy: 0.8906, test_Accuracy: 0.9074
# Epoch: [ 0] [   89/  468] time: 25.3167, train_loss: 0.27476162, train_accuracy: 0.8828, test_Accuracy: 0.9076
# Epoch: [ 0] [   90/  468] time: 25.6648, train_loss: 0.17248037, train_accuracy: 0.9375, test_Accuracy: 0.9090
# Epoch: [ 0] [   91/  468] time: 25.9013, train_loss: 0.34805340, train_accuracy: 0.9062, test_Accuracy: 0.9107
# Epoch: [ 0] [   92/  468] time: 26.1476, train_loss: 0.30202484, train_accuracy: 0.9141, test_Accuracy: 0.9096
# Epoch: [ 0] [   93/  468] time: 26.3805, train_loss: 0.38187349, train_accuracy: 0.8906, test_Accuracy: 0.9099
# Epoch: [ 0] [   94/  468] time: 26.6249, train_loss: 0.34308550, train_accuracy: 0.9062, test_Accuracy: 0.9117
# Epoch: [ 0] [   95/  468] time: 26.9792, train_loss: 0.35648853, train_accuracy: 0.8750, test_Accuracy: 0.9136
# Epoch: [ 0] [   96/  468] time: 27.2090, train_loss: 0.23483053, train_accuracy: 0.9531, test_Accuracy: 0.9133
# Epoch: [ 0] [   97/  468] time: 27.4454, train_loss: 0.39206278, train_accuracy: 0.8906, test_Accuracy: 0.9154
# Epoch: [ 0] [   98/  468] time: 27.7932, train_loss: 0.32412949, train_accuracy: 0.9062, test_Accuracy: 0.9172
# Epoch: [ 0] [   99/  468] time: 28.0256, train_loss: 0.30226505, train_accuracy: 0.9219, test_Accuracy: 0.9165
# Epoch: [ 0] [  100/  468] time: 28.2439, train_loss: 0.23377806, train_accuracy: 0.9219, test_Accuracy: 0.9165
# Epoch: [ 0] [  101/  468] time: 28.5967, train_loss: 0.45941132, train_accuracy: 0.8516, test_Accuracy: 0.9162
# Epoch: [ 0] [  102/  468] time: 28.8127, train_loss: 0.30273175, train_accuracy: 0.8984, test_Accuracy: 0.9165
# Epoch: [ 0] [  103/  468] time: 29.0587, train_loss: 0.27581632, train_accuracy: 0.8828, test_Accuracy: 0.9158
# Epoch: [ 0] [  104/  468] time: 29.2862, train_loss: 0.27837303, train_accuracy: 0.9062, test_Accuracy: 0.9186
# Epoch: [ 0] [  105/  468] time: 29.6338, train_loss: 0.16075438, train_accuracy: 0.9453, test_Accuracy: 0.9192
# Epoch: [ 0] [  106/  468] time: 29.8724, train_loss: 0.30067915, train_accuracy: 0.9062, test_Accuracy: 0.9203
# Epoch: [ 0] [  107/  468] time: 30.1081, train_loss: 0.28413826, train_accuracy: 0.9375, test_Accuracy: 0.9205
# Epoch: [ 0] [  108/  468] time: 30.3333, train_loss: 0.24887499, train_accuracy: 0.9375, test_Accuracy: 0.9193
# Epoch: [ 0] [  109/  468] time: 30.5493, train_loss: 0.30005088, train_accuracy: 0.8906, test_Accuracy: 0.9207
# Epoch: [ 0] [  110/  468] time: 30.7650, train_loss: 0.29206407, train_accuracy: 0.8906, test_Accuracy: 0.9218
# Epoch: [ 0] [  111/  468] time: 30.9918, train_loss: 0.25625452, train_accuracy: 0.9297, test_Accuracy: 0.9253
# Epoch: [ 0] [  112/  468] time: 31.2287, train_loss: 0.20634182, train_accuracy: 0.9453, test_Accuracy: 0.9234
# Epoch: [ 0] [  113/  468] time: 31.4740, train_loss: 0.24754792, train_accuracy: 0.9453, test_Accuracy: 0.9201
# Epoch: [ 0] [  114/  468] time: 31.7132, train_loss: 0.19757263, train_accuracy: 0.9531, test_Accuracy: 0.9172
# Epoch: [ 0] [  115/  468] time: 31.9396, train_loss: 0.30610847, train_accuracy: 0.8828, test_Accuracy: 0.9197
# Epoch: [ 0] [  116/  468] time: 32.1482, train_loss: 0.44117576, train_accuracy: 0.8906, test_Accuracy: 0.9250
# Epoch: [ 0] [  117/  468] time: 32.3717, train_loss: 0.14777514, train_accuracy: 0.9375, test_Accuracy: 0.9258
# Epoch: [ 0] [  118/  468] time: 32.7189, train_loss: 0.25618649, train_accuracy: 0.9297, test_Accuracy: 0.9261
# Epoch: [ 0] [  119/  468] time: 32.9444, train_loss: 0.19911948, train_accuracy: 0.9297, test_Accuracy: 0.9232
# Epoch: [ 0] [  120/  468] time: 33.1556, train_loss: 0.19899586, train_accuracy: 0.9297, test_Accuracy: 0.9191
# Epoch: [ 0] [  121/  468] time: 33.3886, train_loss: 0.29707026, train_accuracy: 0.9062, test_Accuracy: 0.9194
# Epoch: [ 0] [  122/  468] time: 33.6260, train_loss: 0.31292439, train_accuracy: 0.9141, test_Accuracy: 0.9226
# Epoch: [ 0] [  123/  468] time: 33.9751, train_loss: 0.20874064, train_accuracy: 0.9609, test_Accuracy: 0.9241
# Epoch: [ 0] [  124/  468] time: 34.2037, train_loss: 0.21778226, train_accuracy: 0.9141, test_Accuracy: 0.9249
# Epoch: [ 0] [  125/  468] time: 34.4357, train_loss: 0.33393252, train_accuracy: 0.9219, test_Accuracy: 0.9240
# Epoch: [ 0] [  126/  468] time: 34.7841, train_loss: 0.26014739, train_accuracy: 0.9141, test_Accuracy: 0.9236
# Epoch: [ 0] [  127/  468] time: 35.0409, train_loss: 0.34331232, train_accuracy: 0.8750, test_Accuracy: 0.9225
# Epoch: [ 0] [  128/  468] time: 35.4022, train_loss: 0.19649346, train_accuracy: 0.9531, test_Accuracy: 0.9220
# Epoch: [ 0] [  129/  468] time: 35.7848, train_loss: 0.20463760, train_accuracy: 0.9375, test_Accuracy: 0.9203
# Epoch: [ 0] [  130/  468] time: 36.1410, train_loss: 0.18323007, train_accuracy: 0.9453, test_Accuracy: 0.9202
# Epoch: [ 0] [  131/  468] time: 37.4689, train_loss: 0.17118070, train_accuracy: 0.9531, test_Accuracy: 0.9211
# Epoch: [ 0] [  132/  468] time: 37.8110, train_loss: 0.25352392, train_accuracy: 0.9375, test_Accuracy: 0.9229
# Epoch: [ 0] [  133/  468] time: 38.0378, train_loss: 0.22924784, train_accuracy: 0.9375, test_Accuracy: 0.9217
# Epoch: [ 0] [  134/  468] time: 38.2529, train_loss: 0.31546408, train_accuracy: 0.9141, test_Accuracy: 0.9231
# Epoch: [ 0] [  135/  468] time: 38.4841, train_loss: 0.30826589, train_accuracy: 0.9062, test_Accuracy: 0.9249
# Epoch: [ 0] [  136/  468] time: 38.8368, train_loss: 0.18169099, train_accuracy: 0.9375, test_Accuracy: 0.9266
# Epoch: [ 0] [  137/  468] time: 39.0903, train_loss: 0.22476913, train_accuracy: 0.9219, test_Accuracy: 0.9271
# Epoch: [ 0] [  138/  468] time: 39.3161, train_loss: 0.15864725, train_accuracy: 0.9531, test_Accuracy: 0.9257
# Epoch: [ 0] [  139/  468] time: 39.5335, train_loss: 0.25661734, train_accuracy: 0.9219, test_Accuracy: 0.9235
# Epoch: [ 0] [  140/  468] time: 39.7801, train_loss: 0.28749228, train_accuracy: 0.8906, test_Accuracy: 0.9232
# Epoch: [ 0] [  141/  468] time: 40.0100, train_loss: 0.33977962, train_accuracy: 0.8750, test_Accuracy: 0.9203
# Epoch: [ 0] [  142/  468] time: 40.2264, train_loss: 0.31288499, train_accuracy: 0.9062, test_Accuracy: 0.9224
# Epoch: [ 0] [  143/  468] time: 40.4775, train_loss: 0.27294573, train_accuracy: 0.9219, test_Accuracy: 0.9264
# Epoch: [ 0] [  144/  468] time: 40.7119, train_loss: 0.26054794, train_accuracy: 0.9062, test_Accuracy: 0.9266
# Epoch: [ 0] [  145/  468] time: 41.0617, train_loss: 0.22205779, train_accuracy: 0.9062, test_Accuracy: 0.9268
# Epoch: [ 0] [  146/  468] time: 41.4113, train_loss: 0.17242479, train_accuracy: 0.9609, test_Accuracy: 0.9269
# Epoch: [ 0] [  147/  468] time: 41.7611, train_loss: 0.13686369, train_accuracy: 0.9609, test_Accuracy: 0.9263
# Epoch: [ 0] [  148/  468] time: 42.0027, train_loss: 0.31815583, train_accuracy: 0.9453, test_Accuracy: 0.9244
# Epoch: [ 0] [  149/  468] time: 42.2389, train_loss: 0.27115110, train_accuracy: 0.9297, test_Accuracy: 0.9273
# Epoch: [ 0] [  150/  468] time: 42.4635, train_loss: 0.16399825, train_accuracy: 0.9453, test_Accuracy: 0.9306
# Epoch: [ 0] [  151/  468] time: 42.6871, train_loss: 0.25287569, train_accuracy: 0.9219, test_Accuracy: 0.9328
# Epoch: [ 0] [  152/  468] time: 42.9260, train_loss: 0.22668758, train_accuracy: 0.9219, test_Accuracy: 0.9320
# Epoch: [ 0] [  153/  468] time: 43.1565, train_loss: 0.33517987, train_accuracy: 0.9297, test_Accuracy: 0.9302
# Epoch: [ 0] [  154/  468] time: 43.3906, train_loss: 0.18027788, train_accuracy: 0.9453, test_Accuracy: 0.9282
# Epoch: [ 0] [  155/  468] time: 43.6079, train_loss: 0.19517447, train_accuracy: 0.9219, test_Accuracy: 0.9280
# Epoch: [ 0] [  156/  468] time: 43.9569, train_loss: 0.19292454, train_accuracy: 0.9453, test_Accuracy: 0.9293
# Epoch: [ 0] [  157/  468] time: 44.1894, train_loss: 0.13404921, train_accuracy: 0.9531, test_Accuracy: 0.9297
# Epoch: [ 0] [  158/  468] time: 44.4177, train_loss: 0.42075455, train_accuracy: 0.8672, test_Accuracy: 0.9306
# Epoch: [ 0] [  159/  468] time: 44.6657, train_loss: 0.23226397, train_accuracy: 0.9453, test_Accuracy: 0.9321
# Epoch: [ 0] [  160/  468] time: 44.8976, train_loss: 0.13911071, train_accuracy: 0.9531, test_Accuracy: 0.9313
# Epoch: [ 0] [  161/  468] time: 45.1362, train_loss: 0.20616588, train_accuracy: 0.9297, test_Accuracy: 0.9302
# Epoch: [ 0] [  162/  468] time: 45.3645, train_loss: 0.27451915, train_accuracy: 0.9062, test_Accuracy: 0.9319
# Epoch: [ 0] [  163/  468] time: 45.5912, train_loss: 0.22429155, train_accuracy: 0.9609, test_Accuracy: 0.9312
# Epoch: [ 0] [  164/  468] time: 45.8299, train_loss: 0.25622171, train_accuracy: 0.9453, test_Accuracy: 0.9324
# Epoch: [ 0] [  165/  468] time: 46.1240, train_loss: 0.15376279, train_accuracy: 0.9688, test_Accuracy: 0.9320
# Epoch: [ 0] [  166/  468] time: 46.7459, train_loss: 0.09989358, train_accuracy: 0.9609, test_Accuracy: 0.9327
# Epoch: [ 0] [  167/  468] time: 46.9643, train_loss: 0.26419094, train_accuracy: 0.9297, test_Accuracy: 0.9313
# Epoch: [ 0] [  168/  468] time: 47.3150, train_loss: 0.30079252, train_accuracy: 0.9062, test_Accuracy: 0.9335
# Epoch: [ 0] [  169/  468] time: 47.5498, train_loss: 0.39062822, train_accuracy: 0.8984, test_Accuracy: 0.9348
# Epoch: [ 0] [  170/  468] time: 47.7688, train_loss: 0.18573111, train_accuracy: 0.9531, test_Accuracy: 0.9331
# Epoch: [ 0] [  171/  468] time: 48.1486, train_loss: 0.22855203, train_accuracy: 0.9453, test_Accuracy: 0.9347
# Epoch: [ 0] [  172/  468] time: 48.5390, train_loss: 0.19507678, train_accuracy: 0.9219, test_Accuracy: 0.9322
# Epoch: [ 0] [  173/  468] time: 48.9081, train_loss: 0.18067172, train_accuracy: 0.9297, test_Accuracy: 0.9335
# Epoch: [ 0] [  174/  468] time: 49.2813, train_loss: 0.14536494, train_accuracy: 0.9531, test_Accuracy: 0.9321
# Epoch: [ 0] [  175/  468] time: 49.9765, train_loss: 0.20174594, train_accuracy: 0.9531, test_Accuracy: 0.9315
# Epoch: [ 0] [  176/  468] time: 50.3538, train_loss: 0.16454920, train_accuracy: 0.9297, test_Accuracy: 0.9309
# Epoch: [ 0] [  177/  468] time: 50.5812, train_loss: 0.19239235, train_accuracy: 0.9375, test_Accuracy: 0.9298
# Epoch: [ 0] [  178/  468] time: 50.8162, train_loss: 0.15607783, train_accuracy: 0.9609, test_Accuracy: 0.9295
# Epoch: [ 0] [  179/  468] time: 51.0345, train_loss: 0.29284826, train_accuracy: 0.8984, test_Accuracy: 0.9298
# Epoch: [ 0] [  180/  468] time: 51.2766, train_loss: 0.27439088, train_accuracy: 0.9141, test_Accuracy: 0.9277
# Epoch: [ 0] [  181/  468] time: 51.4916, train_loss: 0.29057091, train_accuracy: 0.9062, test_Accuracy: 0.9267
# Epoch: [ 0] [  182/  468] time: 51.7023, train_loss: 0.22926734, train_accuracy: 0.9453, test_Accuracy: 0.9256
# Epoch: [ 0] [  183/  468] time: 51.9392, train_loss: 0.24393600, train_accuracy: 0.9219, test_Accuracy: 0.9279
# Epoch: [ 0] [  184/  468] time: 52.2870, train_loss: 0.11778316, train_accuracy: 0.9609, test_Accuracy: 0.9272
# Epoch: [ 0] [  185/  468] time: 53.1077, train_loss: 0.24861999, train_accuracy: 0.9219, test_Accuracy: 0.9262
# Epoch: [ 0] [  186/  468] time: 53.5628, train_loss: 0.22559626, train_accuracy: 0.9375, test_Accuracy: 0.9271
# Epoch: [ 0] [  187/  468] time: 54.0081, train_loss: 0.27028835, train_accuracy: 0.9297, test_Accuracy: 0.9286
# Epoch: [ 0] [  188/  468] time: 54.2576, train_loss: 0.22409543, train_accuracy: 0.9219, test_Accuracy: 0.9324
# Epoch: [ 0] [  189/  468] time: 54.4992, train_loss: 0.21333709, train_accuracy: 0.9375, test_Accuracy: 0.9327
# Epoch: [ 0] [  190/  468] time: 54.8506, train_loss: 0.17561695, train_accuracy: 0.9453, test_Accuracy: 0.9342
# Epoch: [ 0] [  191/  468] time: 55.0963, train_loss: 0.10403666, train_accuracy: 0.9766, test_Accuracy: 0.9367
# Epoch: [ 0] [  192/  468] time: 55.4437, train_loss: 0.20053230, train_accuracy: 0.9766, test_Accuracy: 0.9364
# Epoch: [ 0] [  193/  468] time: 55.6658, train_loss: 0.24982643, train_accuracy: 0.9219, test_Accuracy: 0.9360
# Epoch: [ 0] [  194/  468] time: 56.0137, train_loss: 0.16740987, train_accuracy: 0.9453, test_Accuracy: 0.9366
# Epoch: [ 0] [  195/  468] time: 56.2340, train_loss: 0.25488645, train_accuracy: 0.9375, test_Accuracy: 0.9377
# Epoch: [ 0] [  196/  468] time: 56.4629, train_loss: 0.19091687, train_accuracy: 0.9453, test_Accuracy: 0.9379
# Epoch: [ 0] [  197/  468] time: 56.6910, train_loss: 0.16052900, train_accuracy: 0.9609, test_Accuracy: 0.9387
# Epoch: [ 0] [  198/  468] time: 56.9291, train_loss: 0.15533027, train_accuracy: 0.9531, test_Accuracy: 0.9381
# Epoch: [ 0] [  199/  468] time: 57.2797, train_loss: 0.13665947, train_accuracy: 0.9531, test_Accuracy: 0.9369
# Epoch: [ 0] [  200/  468] time: 57.4945, train_loss: 0.23744574, train_accuracy: 0.9375, test_Accuracy: 0.9349
# Epoch: [ 0] [  201/  468] time: 57.7175, train_loss: 0.22700331, train_accuracy: 0.9297, test_Accuracy: 0.9352
# Epoch: [ 0] [  202/  468] time: 57.9442, train_loss: 0.29151598, train_accuracy: 0.9297, test_Accuracy: 0.9357
# Epoch: [ 0] [  203/  468] time: 58.1866, train_loss: 0.20264632, train_accuracy: 0.9375, test_Accuracy: 0.9347
# Epoch: [ 0] [  204/  468] time: 58.4223, train_loss: 0.18659069, train_accuracy: 0.9766, test_Accuracy: 0.9327
# Epoch: [ 0] [  205/  468] time: 58.7695, train_loss: 0.30158353, train_accuracy: 0.9141, test_Accuracy: 0.9329
# Epoch: [ 0] [  206/  468] time: 58.9886, train_loss: 0.20833774, train_accuracy: 0.8984, test_Accuracy: 0.9345
# Epoch: [ 0] [  207/  468] time: 59.2329, train_loss: 0.22859879, train_accuracy: 0.9375, test_Accuracy: 0.9358
# Epoch: [ 0] [  208/  468] time: 59.4747, train_loss: 0.27398190, train_accuracy: 0.9062, test_Accuracy: 0.9367
# Epoch: [ 0] [  209/  468] time: 59.7013, train_loss: 0.25491363, train_accuracy: 0.9219, test_Accuracy: 0.9387
# Epoch: [ 0] [  210/  468] time: 59.9358, train_loss: 0.22972552, train_accuracy: 0.9375, test_Accuracy: 0.9398
# Epoch: [ 0] [  211/  468] time: 60.2860, train_loss: 0.21931432, train_accuracy: 0.9453, test_Accuracy: 0.9426
# Epoch: [ 0] [  212/  468] time: 60.6587, train_loss: 0.18566725, train_accuracy: 0.9453, test_Accuracy: 0.9437
# Epoch: [ 0] [  213/  468] time: 61.0299, train_loss: 0.27671438, train_accuracy: 0.9453, test_Accuracy: 0.9442
# Epoch: [ 0] [  214/  468] time: 61.3970, train_loss: 0.23956412, train_accuracy: 0.9219, test_Accuracy: 0.9439
# Epoch: [ 0] [  215/  468] time: 61.7269, train_loss: 0.17642327, train_accuracy: 0.9453, test_Accuracy: 0.9429
# Epoch: [ 0] [  216/  468] time: 62.1046, train_loss: 0.16181803, train_accuracy: 0.9453, test_Accuracy: 0.9412
# Epoch: [ 0] [  217/  468] time: 62.4707, train_loss: 0.19727665, train_accuracy: 0.9375, test_Accuracy: 0.9421
# Epoch: [ 0] [  218/  468] time: 62.8329, train_loss: 0.14032252, train_accuracy: 0.9609, test_Accuracy: 0.9410
# Epoch: [ 0] [  219/  468] time: 63.0745, train_loss: 0.31072932, train_accuracy: 0.9062, test_Accuracy: 0.9395
# Epoch: [ 0] [  220/  468] time: 63.3263, train_loss: 0.29295450, train_accuracy: 0.8984, test_Accuracy: 0.9408
# Epoch: [ 0] [  221/  468] time: 63.5581, train_loss: 0.16217305, train_accuracy: 0.9375, test_Accuracy: 0.9411
# Epoch: [ 0] [  222/  468] time: 63.7982, train_loss: 0.31974137, train_accuracy: 0.9531, test_Accuracy: 0.9415
# Epoch: [ 0] [  223/  468] time: 64.1481, train_loss: 0.12486394, train_accuracy: 0.9688, test_Accuracy: 0.9408
# Epoch: [ 0] [  224/  468] time: 64.3670, train_loss: 0.22982073, train_accuracy: 0.9297, test_Accuracy: 0.9414
# Epoch: [ 0] [  225/  468] time: 64.7136, train_loss: 0.16092302, train_accuracy: 0.9609, test_Accuracy: 0.9439
# Epoch: [ 0] [  226/  468] time: 64.9468, train_loss: 0.14421786, train_accuracy: 0.9609, test_Accuracy: 0.9431
# Epoch: [ 0] [  227/  468] time: 65.1755, train_loss: 0.18907222, train_accuracy: 0.9453, test_Accuracy: 0.9438
# Epoch: [ 0] [  228/  468] time: 65.4037, train_loss: 0.14134452, train_accuracy: 0.9531, test_Accuracy: 0.9426
# Epoch: [ 0] [  229/  468] time: 65.7539, train_loss: 0.20178165, train_accuracy: 0.9297, test_Accuracy: 0.9425
# Epoch: [ 0] [  230/  468] time: 65.9898, train_loss: 0.18053690, train_accuracy: 0.9453, test_Accuracy: 0.9433
# Epoch: [ 0] [  231/  468] time: 66.1958, train_loss: 0.15179816, train_accuracy: 0.9453, test_Accuracy: 0.9433
# Epoch: [ 0] [  232/  468] time: 66.4044, train_loss: 0.12574027, train_accuracy: 0.9453, test_Accuracy: 0.9435
# Epoch: [ 0] [  233/  468] time: 66.6237, train_loss: 0.16421260, train_accuracy: 0.9766, test_Accuracy: 0.9440
# Epoch: [ 0] [  234/  468] time: 66.8527, train_loss: 0.14709799, train_accuracy: 0.9531, test_Accuracy: 0.9447
# Epoch: [ 0] [  235/  468] time: 67.0741, train_loss: 0.14616770, train_accuracy: 0.9609, test_Accuracy: 0.9437
# Epoch: [ 0] [  236/  468] time: 67.4206, train_loss: 0.28364301, train_accuracy: 0.8984, test_Accuracy: 0.9426
# Epoch: [ 0] [  237/  468] time: 67.6209, train_loss: 0.09705611, train_accuracy: 0.9609, test_Accuracy: 0.9428
# Epoch: [ 0] [  238/  468] time: 67.8667, train_loss: 0.17967358, train_accuracy: 0.9609, test_Accuracy: 0.9446
# Epoch: [ 0] [  239/  468] time: 68.1186, train_loss: 0.22379267, train_accuracy: 0.9297, test_Accuracy: 0.9460
# Epoch: [ 0] [  240/  468] time: 68.3414, train_loss: 0.18580769, train_accuracy: 0.9609, test_Accuracy: 0.9466
# Epoch: [ 0] [  241/  468] time: 68.5275, train_loss: 0.23071927, train_accuracy: 0.9609, test_Accuracy: 0.9456
# Epoch: [ 0] [  242/  468] time: 68.7701, train_loss: 0.17681468, train_accuracy: 0.9609, test_Accuracy: 0.9425
# Epoch: [ 0] [  243/  468] time: 68.9905, train_loss: 0.20300117, train_accuracy: 0.9219, test_Accuracy: 0.9403
# Epoch: [ 0] [  244/  468] time: 69.1956, train_loss: 0.21642926, train_accuracy: 0.9219, test_Accuracy: 0.9397
# Epoch: [ 0] [  245/  468] time: 69.4179, train_loss: 0.25231633, train_accuracy: 0.9453, test_Accuracy: 0.9391
# Epoch: [ 0] [  246/  468] time: 69.6392, train_loss: 0.17471467, train_accuracy: 0.9531, test_Accuracy: 0.9400
# Epoch: [ 0] [  247/  468] time: 69.9891, train_loss: 0.14427911, train_accuracy: 0.9453, test_Accuracy: 0.9405
# Epoch: [ 0] [  248/  468] time: 70.2100, train_loss: 0.24910100, train_accuracy: 0.9375, test_Accuracy: 0.9418
# Epoch: [ 0] [  249/  468] time: 70.4316, train_loss: 0.18037245, train_accuracy: 0.9453, test_Accuracy: 0.9423
# Epoch: [ 0] [  250/  468] time: 70.6536, train_loss: 0.17968850, train_accuracy: 0.9297, test_Accuracy: 0.9433
# Epoch: [ 0] [  251/  468] time: 70.8780, train_loss: 0.17530379, train_accuracy: 0.9453, test_Accuracy: 0.9445
# Epoch: [ 0] [  252/  468] time: 71.1253, train_loss: 0.19247907, train_accuracy: 0.9219, test_Accuracy: 0.9462
# Epoch: [ 0] [  253/  468] time: 71.4796, train_loss: 0.11364514, train_accuracy: 0.9609, test_Accuracy: 0.9461
# Epoch: [ 0] [  254/  468] time: 71.7142, train_loss: 0.24225222, train_accuracy: 0.9375, test_Accuracy: 0.9470
# Epoch: [ 0] [  255/  468] time: 71.9652, train_loss: 0.24856380, train_accuracy: 0.9297, test_Accuracy: 0.9470
# Epoch: [ 0] [  256/  468] time: 72.3147, train_loss: 0.22060828, train_accuracy: 0.9297, test_Accuracy: 0.9472
# Epoch: [ 0] [  257/  468] time: 72.5520, train_loss: 0.17289765, train_accuracy: 0.9609, test_Accuracy: 0.9471
# Epoch: [ 0] [  258/  468] time: 72.9108, train_loss: 0.17224921, train_accuracy: 0.9531, test_Accuracy: 0.9478
# Epoch: [ 0] [  259/  468] time: 73.2974, train_loss: 0.20809402, train_accuracy: 0.9297, test_Accuracy: 0.9479
# Epoch: [ 0] [  260/  468] time: 73.6661, train_loss: 0.14465752, train_accuracy: 0.9688, test_Accuracy: 0.9478
# Epoch: [ 0] [  261/  468] time: 74.0598, train_loss: 0.13757014, train_accuracy: 0.9688, test_Accuracy: 0.9489
# Epoch: [ 0] [  262/  468] time: 74.4278, train_loss: 0.23400813, train_accuracy: 0.9219, test_Accuracy: 0.9488
# Epoch: [ 0] [  263/  468] time: 74.7657, train_loss: 0.15954816, train_accuracy: 0.9531, test_Accuracy: 0.9454
# Epoch: [ 0] [  264/  468] time: 75.1125, train_loss: 0.23600879, train_accuracy: 0.9453, test_Accuracy: 0.9423
# Epoch: [ 0] [  265/  468] time: 75.4584, train_loss: 0.21764252, train_accuracy: 0.9375, test_Accuracy: 0.9427
# Epoch: [ 0] [  266/  468] time: 75.7330, train_loss: 0.17629701, train_accuracy: 0.9531, test_Accuracy: 0.9446
# Epoch: [ 0] [  267/  468] time: 75.9726, train_loss: 0.14350042, train_accuracy: 0.9453, test_Accuracy: 0.9454
# Epoch: [ 0] [  268/  468] time: 76.1908, train_loss: 0.17585434, train_accuracy: 0.9453, test_Accuracy: 0.9454
# Epoch: [ 0] [  269/  468] time: 76.4321, train_loss: 0.16681650, train_accuracy: 0.9688, test_Accuracy: 0.9460
# Epoch: [ 0] [  270/  468] time: 76.7830, train_loss: 0.25795043, train_accuracy: 0.9062, test_Accuracy: 0.9468
# Epoch: [ 0] [  271/  468] time: 77.0392, train_loss: 0.11816718, train_accuracy: 0.9688, test_Accuracy: 0.9482
# Epoch: [ 0] [  272/  468] time: 77.2736, train_loss: 0.17735340, train_accuracy: 0.9688, test_Accuracy: 0.9487
# Epoch: [ 0] [  273/  468] time: 77.6256, train_loss: 0.17854831, train_accuracy: 0.9609, test_Accuracy: 0.9489
# Epoch: [ 0] [  274/  468] time: 77.8593, train_loss: 0.15753691, train_accuracy: 0.9531, test_Accuracy: 0.9491
# Epoch: [ 0] [  275/  468] time: 78.1019, train_loss: 0.19287229, train_accuracy: 0.9688, test_Accuracy: 0.9474
# Epoch: [ 0] [  276/  468] time: 78.3285, train_loss: 0.22573823, train_accuracy: 0.9453, test_Accuracy: 0.9469
# Epoch: [ 0] [  277/  468] time: 78.5545, train_loss: 0.11312687, train_accuracy: 0.9688, test_Accuracy: 0.9465
# Epoch: [ 0] [  278/  468] time: 78.7759, train_loss: 0.13087887, train_accuracy: 0.9453, test_Accuracy: 0.9480
# Epoch: [ 0] [  279/  468] time: 79.0151, train_loss: 0.11010855, train_accuracy: 0.9688, test_Accuracy: 0.9482
# Epoch: [ 0] [  280/  468] time: 79.2600, train_loss: 0.16472121, train_accuracy: 0.9453, test_Accuracy: 0.9479
# Epoch: [ 0] [  281/  468] time: 79.4773, train_loss: 0.08375191, train_accuracy: 0.9844, test_Accuracy: 0.9479
# Epoch: [ 0] [  282/  468] time: 79.7081, train_loss: 0.18054914, train_accuracy: 0.9453, test_Accuracy: 0.9471
# Epoch: [ 0] [  283/  468] time: 79.9471, train_loss: 0.15891345, train_accuracy: 0.9375, test_Accuracy: 0.9486
# Epoch: [ 0] [  284/  468] time: 80.2945, train_loss: 0.13933846, train_accuracy: 0.9609, test_Accuracy: 0.9490
# Epoch: [ 0] [  285/  468] time: 80.5348, train_loss: 0.29599321, train_accuracy: 0.9375, test_Accuracy: 0.9497
# Epoch: [ 0] [  286/  468] time: 80.7693, train_loss: 0.09926035, train_accuracy: 0.9766, test_Accuracy: 0.9505
# Epoch: [ 0] [  287/  468] time: 81.0113, train_loss: 0.15146191, train_accuracy: 0.9453, test_Accuracy: 0.9483
# Epoch: [ 0] [  288/  468] time: 81.2545, train_loss: 0.14731425, train_accuracy: 0.9297, test_Accuracy: 0.9475
# Epoch: [ 0] [  289/  468] time: 81.4860, train_loss: 0.21660757, train_accuracy: 0.9375, test_Accuracy: 0.9488
# Epoch: [ 0] [  290/  468] time: 81.7093, train_loss: 0.28174147, train_accuracy: 0.9297, test_Accuracy: 0.9500
# Epoch: [ 0] [  291/  468] time: 81.9320, train_loss: 0.15063486, train_accuracy: 0.9531, test_Accuracy: 0.9499
# Epoch: [ 0] [  292/  468] time: 82.2869, train_loss: 0.17351377, train_accuracy: 0.9531, test_Accuracy: 0.9495
# Epoch: [ 0] [  293/  468] time: 82.5090, train_loss: 0.20070437, train_accuracy: 0.9375, test_Accuracy: 0.9501
# Epoch: [ 0] [  294/  468] time: 82.8566, train_loss: 0.23989260, train_accuracy: 0.9453, test_Accuracy: 0.9509
# Epoch: [ 0] [  295/  468] time: 83.0903, train_loss: 0.29792464, train_accuracy: 0.9219, test_Accuracy: 0.9527
# Epoch: [ 0] [  296/  468] time: 83.3227, train_loss: 0.17292005, train_accuracy: 0.9453, test_Accuracy: 0.9519
# Epoch: [ 0] [  297/  468] time: 83.5510, train_loss: 0.18513206, train_accuracy: 0.9375, test_Accuracy: 0.9504
# Epoch: [ 0] [  298/  468] time: 83.7850, train_loss: 0.15285861, train_accuracy: 0.9609, test_Accuracy: 0.9495
# Epoch: [ 0] [  299/  468] time: 84.0184, train_loss: 0.17544597, train_accuracy: 0.9609, test_Accuracy: 0.9491
# Epoch: [ 0] [  300/  468] time: 84.2599, train_loss: 0.11249454, train_accuracy: 0.9766, test_Accuracy: 0.9503
# Epoch: [ 0] [  301/  468] time: 84.4950, train_loss: 0.19113737, train_accuracy: 0.9453, test_Accuracy: 0.9490
# Epoch: [ 0] [  302/  468] time: 84.7137, train_loss: 0.17843933, train_accuracy: 0.9453, test_Accuracy: 0.9480
# Epoch: [ 0] [  303/  468] time: 84.9625, train_loss: 0.15621178, train_accuracy: 0.9609, test_Accuracy: 0.9468
# Epoch: [ 0] [  304/  468] time: 85.1973, train_loss: 0.17300449, train_accuracy: 0.9375, test_Accuracy: 0.9474
# Epoch: [ 0] [  305/  468] time: 85.4313, train_loss: 0.15789436, train_accuracy: 0.9609, test_Accuracy: 0.9475
# Epoch: [ 0] [  306/  468] time: 85.7795, train_loss: 0.13719490, train_accuracy: 0.9531, test_Accuracy: 0.9467
# Epoch: [ 0] [  307/  468] time: 86.1524, train_loss: 0.12136835, train_accuracy: 0.9844, test_Accuracy: 0.9471
# Epoch: [ 0] [  308/  468] time: 86.4826, train_loss: 0.24107045, train_accuracy: 0.9219, test_Accuracy: 0.9482
# Epoch: [ 0] [  309/  468] time: 87.1764, train_loss: 0.13489947, train_accuracy: 0.9531, test_Accuracy: 0.9482
# Epoch: [ 0] [  310/  468] time: 87.5517, train_loss: 0.20930764, train_accuracy: 0.9453, test_Accuracy: 0.9494
# Epoch: [ 0] [  311/  468] time: 87.9342, train_loss: 0.12177393, train_accuracy: 0.9609, test_Accuracy: 0.9484
# Epoch: [ 0] [  312/  468] time: 88.2079, train_loss: 0.10679063, train_accuracy: 0.9531, test_Accuracy: 0.9489
# Epoch: [ 0] [  313/  468] time: 88.4248, train_loss: 0.21211922, train_accuracy: 0.9375, test_Accuracy: 0.9482
# Epoch: [ 0] [  314/  468] time: 88.6566, train_loss: 0.13411032, train_accuracy: 0.9688, test_Accuracy: 0.9464
# Epoch: [ 0] [  315/  468] time: 88.8836, train_loss: 0.12705886, train_accuracy: 0.9688, test_Accuracy: 0.9472
# Epoch: [ 0] [  316/  468] time: 89.1253, train_loss: 0.25033781, train_accuracy: 0.9141, test_Accuracy: 0.9496
# Epoch: [ 0] [  317/  468] time: 89.3408, train_loss: 0.09817910, train_accuracy: 0.9844, test_Accuracy: 0.9523
# Epoch: [ 0] [  318/  468] time: 89.5709, train_loss: 0.21952426, train_accuracy: 0.9531, test_Accuracy: 0.9535
# Epoch: [ 0] [  319/  468] time: 89.8130, train_loss: 0.28300929, train_accuracy: 0.9453, test_Accuracy: 0.9527
# Epoch: [ 0] [  320/  468] time: 90.0342, train_loss: 0.14442381, train_accuracy: 0.9766, test_Accuracy: 0.9515
# Epoch: [ 0] [  321/  468] time: 90.3819, train_loss: 0.16801180, train_accuracy: 0.9609, test_Accuracy: 0.9508
# Epoch: [ 0] [  322/  468] time: 90.6202, train_loss: 0.15656556, train_accuracy: 0.9609, test_Accuracy: 0.9498
# Epoch: [ 0] [  323/  468] time: 90.9680, train_loss: 0.19682953, train_accuracy: 0.9609, test_Accuracy: 0.9484
# Epoch: [ 0] [  324/  468] time: 91.1890, train_loss: 0.18055931, train_accuracy: 0.9375, test_Accuracy: 0.9469
# Epoch: [ 0] [  325/  468] time: 91.5406, train_loss: 0.08519276, train_accuracy: 0.9922, test_Accuracy: 0.9470
# Epoch: [ 0] [  326/  468] time: 91.7570, train_loss: 0.13104416, train_accuracy: 0.9609, test_Accuracy: 0.9485
# Epoch: [ 0] [  327/  468] time: 91.9896, train_loss: 0.26008379, train_accuracy: 0.8984, test_Accuracy: 0.9515
# Epoch: [ 0] [  328/  468] time: 92.2356, train_loss: 0.14871678, train_accuracy: 0.9688, test_Accuracy: 0.9537
# Epoch: [ 0] [  329/  468] time: 92.4775, train_loss: 0.07819729, train_accuracy: 0.9922, test_Accuracy: 0.9544
# Epoch: [ 0] [  330/  468] time: 92.7062, train_loss: 0.13687485, train_accuracy: 0.9688, test_Accuracy: 0.9538
# Epoch: [ 0] [  331/  468] time: 92.9200, train_loss: 0.15998811, train_accuracy: 0.9531, test_Accuracy: 0.9499
# Epoch: [ 0] [  332/  468] time: 93.2684, train_loss: 0.12851959, train_accuracy: 0.9766, test_Accuracy: 0.9480
# Epoch: [ 0] [  333/  468] time: 93.5127, train_loss: 0.14239193, train_accuracy: 0.9609, test_Accuracy: 0.9472
# Epoch: [ 0] [  334/  468] time: 93.7210, train_loss: 0.23873541, train_accuracy: 0.9531, test_Accuracy: 0.9461
# Epoch: [ 0] [  335/  468] time: 93.9594, train_loss: 0.11141607, train_accuracy: 0.9766, test_Accuracy: 0.9478
# Epoch: [ 0] [  336/  468] time: 94.1966, train_loss: 0.09494150, train_accuracy: 0.9844, test_Accuracy: 0.9496
# Epoch: [ 0] [  337/  468] time: 94.4227, train_loss: 0.19038865, train_accuracy: 0.9375, test_Accuracy: 0.9525
# Epoch: [ 0] [  338/  468] time: 94.6739, train_loss: 0.18788709, train_accuracy: 0.9297, test_Accuracy: 0.9515
# Epoch: [ 0] [  339/  468] time: 94.8882, train_loss: 0.09803885, train_accuracy: 0.9766, test_Accuracy: 0.9514
# Epoch: [ 0] [  340/  468] time: 95.2390, train_loss: 0.10439863, train_accuracy: 0.9766, test_Accuracy: 0.9510
# Epoch: [ 0] [  341/  468] time: 95.4670, train_loss: 0.18206725, train_accuracy: 0.9609, test_Accuracy: 0.9503
# Epoch: [ 0] [  342/  468] time: 95.6865, train_loss: 0.10439609, train_accuracy: 0.9609, test_Accuracy: 0.9495
# Epoch: [ 0] [  343/  468] time: 95.9117, train_loss: 0.14572820, train_accuracy: 0.9609, test_Accuracy: 0.9517
# Epoch: [ 0] [  344/  468] time: 96.2634, train_loss: 0.10757139, train_accuracy: 0.9766, test_Accuracy: 0.9525
# Epoch: [ 0] [  345/  468] time: 96.4987, train_loss: 0.11394140, train_accuracy: 0.9609, test_Accuracy: 0.9526
# Epoch: [ 0] [  346/  468] time: 96.7370, train_loss: 0.14482510, train_accuracy: 0.9453, test_Accuracy: 0.9546
# Epoch: [ 0] [  347/  468] time: 96.9555, train_loss: 0.13850579, train_accuracy: 0.9609, test_Accuracy: 0.9538
# Epoch: [ 0] [  348/  468] time: 97.1718, train_loss: 0.12919542, train_accuracy: 0.9609, test_Accuracy: 0.9529
# Epoch: [ 0] [  349/  468] time: 97.5244, train_loss: 0.27353194, train_accuracy: 0.9062, test_Accuracy: 0.9513
# Epoch: [ 0] [  350/  468] time: 97.7187, train_loss: 0.12773600, train_accuracy: 0.9531, test_Accuracy: 0.9500
# Epoch: [ 0] [  351/  468] time: 97.9684, train_loss: 0.25823227, train_accuracy: 0.9453, test_Accuracy: 0.9518
# Epoch: [ 0] [  352/  468] time: 98.2289, train_loss: 0.16539487, train_accuracy: 0.9531, test_Accuracy: 0.9529
# Epoch: [ 0] [  353/  468] time: 98.5861, train_loss: 0.29280609, train_accuracy: 0.9141, test_Accuracy: 0.9549
# Epoch: [ 0] [  354/  468] time: 98.9200, train_loss: 0.16275217, train_accuracy: 0.9688, test_Accuracy: 0.9571
# Epoch: [ 0] [  355/  468] time: 99.6095, train_loss: 0.09033224, train_accuracy: 0.9766, test_Accuracy: 0.9582
# Epoch: [ 0] [  356/  468] time: 99.9836, train_loss: 0.07958736, train_accuracy: 0.9844, test_Accuracy: 0.9577
# Epoch: [ 0] [  357/  468] time: 100.3626, train_loss: 0.10309736, train_accuracy: 0.9766, test_Accuracy: 0.9576
# Epoch: [ 0] [  358/  468] time: 100.7361, train_loss: 0.16800517, train_accuracy: 0.9531, test_Accuracy: 0.9576
# Epoch: [ 0] [  359/  468] time: 100.9741, train_loss: 0.15278587, train_accuracy: 0.9453, test_Accuracy: 0.9582
# Epoch: [ 0] [  360/  468] time: 101.2028, train_loss: 0.11203689, train_accuracy: 0.9688, test_Accuracy: 0.9564
# Epoch: [ 0] [  361/  468] time: 101.4338, train_loss: 0.13981181, train_accuracy: 0.9688, test_Accuracy: 0.9573
# Epoch: [ 0] [  362/  468] time: 101.6749, train_loss: 0.10297568, train_accuracy: 0.9688, test_Accuracy: 0.9574
# Epoch: [ 0] [  363/  468] time: 101.8936, train_loss: 0.13616407, train_accuracy: 0.9766, test_Accuracy: 0.9578
# Epoch: [ 0] [  364/  468] time: 102.1325, train_loss: 0.20828179, train_accuracy: 0.9531, test_Accuracy: 0.9589
# Epoch: [ 0] [  365/  468] time: 102.3471, train_loss: 0.12092611, train_accuracy: 0.9766, test_Accuracy: 0.9576
# Epoch: [ 0] [  366/  468] time: 102.5761, train_loss: 0.14055340, train_accuracy: 0.9766, test_Accuracy: 0.9571
# Epoch: [ 0] [  367/  468] time: 102.8153, train_loss: 0.13439517, train_accuracy: 0.9688, test_Accuracy: 0.9565
# Epoch: [ 0] [  368/  468] time: 103.0327, train_loss: 0.13987964, train_accuracy: 0.9688, test_Accuracy: 0.9558
# Epoch: [ 0] [  369/  468] time: 103.2480, train_loss: 0.13595816, train_accuracy: 0.9531, test_Accuracy: 0.9560
# Epoch: [ 0] [  370/  468] time: 103.4725, train_loss: 0.14422613, train_accuracy: 0.9531, test_Accuracy: 0.9568
# Epoch: [ 0] [  371/  468] time: 103.7054, train_loss: 0.16443558, train_accuracy: 0.9453, test_Accuracy: 0.9572
# Epoch: [ 0] [  372/  468] time: 104.0592, train_loss: 0.20904753, train_accuracy: 0.9453, test_Accuracy: 0.9566
# Epoch: [ 0] [  373/  468] time: 104.2979, train_loss: 0.12727576, train_accuracy: 0.9609, test_Accuracy: 0.9575
# Epoch: [ 0] [  374/  468] time: 104.6460, train_loss: 0.10660757, train_accuracy: 0.9609, test_Accuracy: 0.9568
# Epoch: [ 0] [  375/  468] time: 104.8645, train_loss: 0.08726715, train_accuracy: 0.9922, test_Accuracy: 0.9558
# Epoch: [ 0] [  376/  468] time: 105.0840, train_loss: 0.09243953, train_accuracy: 0.9766, test_Accuracy: 0.9549
# Epoch: [ 0] [  377/  468] time: 105.4318, train_loss: 0.10595436, train_accuracy: 0.9688, test_Accuracy: 0.9547
# Epoch: [ 0] [  378/  468] time: 105.6700, train_loss: 0.14828885, train_accuracy: 0.9531, test_Accuracy: 0.9555
# Epoch: [ 0] [  379/  468] time: 106.0194, train_loss: 0.09455863, train_accuracy: 0.9766, test_Accuracy: 0.9558
# Epoch: [ 0] [  380/  468] time: 106.2498, train_loss: 0.09525962, train_accuracy: 0.9766, test_Accuracy: 0.9554
# Epoch: [ 0] [  381/  468] time: 106.4729, train_loss: 0.17821461, train_accuracy: 0.9453, test_Accuracy: 0.9543
# Epoch: [ 0] [  382/  468] time: 106.6954, train_loss: 0.14835586, train_accuracy: 0.9531, test_Accuracy: 0.9544
# Epoch: [ 0] [  383/  468] time: 106.9451, train_loss: 0.12143877, train_accuracy: 0.9609, test_Accuracy: 0.9540
# Epoch: [ 0] [  384/  468] time: 107.1793, train_loss: 0.12372780, train_accuracy: 0.9531, test_Accuracy: 0.9536
# Epoch: [ 0] [  385/  468] time: 107.4018, train_loss: 0.08682250, train_accuracy: 0.9688, test_Accuracy: 0.9561
# Epoch: [ 0] [  386/  468] time: 107.6306, train_loss: 0.18952204, train_accuracy: 0.9453, test_Accuracy: 0.9567
# Epoch: [ 0] [  387/  468] time: 107.8752, train_loss: 0.18177682, train_accuracy: 0.9609, test_Accuracy: 0.9567
# Epoch: [ 0] [  388/  468] time: 108.1050, train_loss: 0.19522317, train_accuracy: 0.9375, test_Accuracy: 0.9575
# Epoch: [ 0] [  389/  468] time: 108.3227, train_loss: 0.13348114, train_accuracy: 0.9531, test_Accuracy: 0.9582
# Epoch: [ 0] [  390/  468] time: 108.6696, train_loss: 0.25084424, train_accuracy: 0.9375, test_Accuracy: 0.9580
# Epoch: [ 0] [  391/  468] time: 108.9191, train_loss: 0.11098417, train_accuracy: 0.9766, test_Accuracy: 0.9576
# Epoch: [ 0] [  392/  468] time: 109.1599, train_loss: 0.10171352, train_accuracy: 0.9766, test_Accuracy: 0.9573
# Epoch: [ 0] [  393/  468] time: 109.3954, train_loss: 0.12909773, train_accuracy: 0.9609, test_Accuracy: 0.9566
# Epoch: [ 0] [  394/  468] time: 109.6240, train_loss: 0.15825251, train_accuracy: 0.9375, test_Accuracy: 0.9564
# Epoch: [ 0] [  395/  468] time: 109.9749, train_loss: 0.17261779, train_accuracy: 0.9375, test_Accuracy: 0.9560
# Epoch: [ 0] [  396/  468] time: 110.2108, train_loss: 0.16108686, train_accuracy: 0.9531, test_Accuracy: 0.9543
# Epoch: [ 0] [  397/  468] time: 110.4230, train_loss: 0.11117754, train_accuracy: 0.9688, test_Accuracy: 0.9533
# Epoch: [ 0] [  398/  468] time: 110.6733, train_loss: 0.11463031, train_accuracy: 0.9688, test_Accuracy: 0.9543
# Epoch: [ 0] [  399/  468] time: 111.0208, train_loss: 0.19655758, train_accuracy: 0.9219, test_Accuracy: 0.9527
# Epoch: [ 0] [  400/  468] time: 111.3904, train_loss: 0.14013684, train_accuracy: 0.9609, test_Accuracy: 0.9494
# Epoch: [ 0] [  401/  468] time: 111.7723, train_loss: 0.10774768, train_accuracy: 0.9531, test_Accuracy: 0.9463
# Epoch: [ 0] [  402/  468] time: 112.1629, train_loss: 0.23360217, train_accuracy: 0.9062, test_Accuracy: 0.9483
# Epoch: [ 0] [  403/  468] time: 112.5070, train_loss: 0.14502814, train_accuracy: 0.9531, test_Accuracy: 0.9501
# Epoch: [ 0] [  404/  468] time: 112.8738, train_loss: 0.06998101, train_accuracy: 0.9766, test_Accuracy: 0.9517
# Epoch: [ 0] [  405/  468] time: 113.2193, train_loss: 0.17247868, train_accuracy: 0.9453, test_Accuracy: 0.9545
# Epoch: [ 0] [  406/  468] time: 113.4889, train_loss: 0.09020483, train_accuracy: 0.9609, test_Accuracy: 0.9564
# Epoch: [ 0] [  407/  468] time: 113.7247, train_loss: 0.13149501, train_accuracy: 0.9453, test_Accuracy: 0.9565
# Epoch: [ 0] [  408/  468] time: 114.0740, train_loss: 0.21492270, train_accuracy: 0.9141, test_Accuracy: 0.9569
# Epoch: [ 0] [  409/  468] time: 114.3044, train_loss: 0.08779074, train_accuracy: 0.9688, test_Accuracy: 0.9566
# Epoch: [ 0] [  410/  468] time: 114.5279, train_loss: 0.14196250, train_accuracy: 0.9688, test_Accuracy: 0.9554
# Epoch: [ 0] [  411/  468] time: 114.7410, train_loss: 0.15752476, train_accuracy: 0.9453, test_Accuracy: 0.9552
# Epoch: [ 0] [  412/  468] time: 114.9730, train_loss: 0.10191328, train_accuracy: 0.9609, test_Accuracy: 0.9558
# Epoch: [ 0] [  413/  468] time: 115.1958, train_loss: 0.14973298, train_accuracy: 0.9531, test_Accuracy: 0.9559
# Epoch: [ 0] [  414/  468] time: 115.4253, train_loss: 0.20104714, train_accuracy: 0.9531, test_Accuracy: 0.9544
# Epoch: [ 0] [  415/  468] time: 115.6669, train_loss: 0.18317609, train_accuracy: 0.9219, test_Accuracy: 0.9544
# Epoch: [ 0] [  416/  468] time: 116.0213, train_loss: 0.09873895, train_accuracy: 0.9688, test_Accuracy: 0.9540
# Epoch: [ 0] [  417/  468] time: 116.2631, train_loss: 0.09693332, train_accuracy: 0.9531, test_Accuracy: 0.9538
# Epoch: [ 0] [  418/  468] time: 116.4981, train_loss: 0.20911828, train_accuracy: 0.9531, test_Accuracy: 0.9548
# Epoch: [ 0] [  419/  468] time: 116.8454, train_loss: 0.17650758, train_accuracy: 0.9453, test_Accuracy: 0.9553
# Epoch: [ 0] [  420/  468] time: 117.0489, train_loss: 0.14580578, train_accuracy: 0.9609, test_Accuracy: 0.9549
# Epoch: [ 0] [  421/  468] time: 117.2837, train_loss: 0.13884409, train_accuracy: 0.9531, test_Accuracy: 0.9553
# Epoch: [ 0] [  422/  468] time: 117.4965, train_loss: 0.18438229, train_accuracy: 0.9375, test_Accuracy: 0.9560
# Epoch: [ 0] [  423/  468] time: 117.7288, train_loss: 0.16473517, train_accuracy: 0.9531, test_Accuracy: 0.9564
# Epoch: [ 0] [  424/  468] time: 117.9571, train_loss: 0.18838938, train_accuracy: 0.9297, test_Accuracy: 0.9571
# Epoch: [ 0] [  425/  468] time: 118.2003, train_loss: 0.11490837, train_accuracy: 0.9688, test_Accuracy: 0.9564
# Epoch: [ 0] [  426/  468] time: 118.4249, train_loss: 0.18060400, train_accuracy: 0.9297, test_Accuracy: 0.9549
# Epoch: [ 0] [  427/  468] time: 118.6584, train_loss: 0.09982094, train_accuracy: 0.9766, test_Accuracy: 0.9554
# Epoch: [ 0] [  428/  468] time: 118.8950, train_loss: 0.10926046, train_accuracy: 0.9688, test_Accuracy: 0.9551
# Epoch: [ 0] [  429/  468] time: 119.1180, train_loss: 0.17666237, train_accuracy: 0.9531, test_Accuracy: 0.9569
# Epoch: [ 0] [  430/  468] time: 119.3637, train_loss: 0.16603471, train_accuracy: 0.9375, test_Accuracy: 0.9571
# Epoch: [ 0] [  431/  468] time: 119.6012, train_loss: 0.13449237, train_accuracy: 0.9531, test_Accuracy: 0.9576
# Epoch: [ 0] [  432/  468] time: 119.8234, train_loss: 0.14340401, train_accuracy: 0.9688, test_Accuracy: 0.9576
# Epoch: [ 0] [  433/  468] time: 120.0417, train_loss: 0.22876707, train_accuracy: 0.9375, test_Accuracy: 0.9566
# Epoch: [ 0] [  434/  468] time: 120.2738, train_loss: 0.10208641, train_accuracy: 0.9609, test_Accuracy: 0.9559
# Epoch: [ 0] [  435/  468] time: 120.6230, train_loss: 0.13493048, train_accuracy: 0.9609, test_Accuracy: 0.9566
# Epoch: [ 0] [  436/  468] time: 120.8437, train_loss: 0.18361409, train_accuracy: 0.9531, test_Accuracy: 0.9556
# Epoch: [ 0] [  437/  468] time: 121.1942, train_loss: 0.10744700, train_accuracy: 0.9609, test_Accuracy: 0.9552
# Epoch: [ 0] [  438/  468] time: 121.4295, train_loss: 0.18809023, train_accuracy: 0.9219, test_Accuracy: 0.9552
# Epoch: [ 0] [  439/  468] time: 121.6524, train_loss: 0.21864626, train_accuracy: 0.9453, test_Accuracy: 0.9565
# Epoch: [ 0] [  440/  468] time: 121.8908, train_loss: 0.18792994, train_accuracy: 0.9297, test_Accuracy: 0.9584
# Epoch: [ 0] [  441/  468] time: 122.2406, train_loss: 0.19064221, train_accuracy: 0.9609, test_Accuracy: 0.9608
# Epoch: [ 0] [  442/  468] time: 122.5933, train_loss: 0.04868496, train_accuracy: 0.9844, test_Accuracy: 0.9601
# Epoch: [ 0] [  443/  468] time: 122.8051, train_loss: 0.10047553, train_accuracy: 0.9609, test_Accuracy: 0.9588
# Epoch: [ 0] [  444/  468] time: 123.0246, train_loss: 0.15504296, train_accuracy: 0.9609, test_Accuracy: 0.9580
# Epoch: [ 0] [  445/  468] time: 123.2690, train_loss: 0.14731821, train_accuracy: 0.9297, test_Accuracy: 0.9579
# Epoch: [ 0] [  446/  468] time: 123.6194, train_loss: 0.08838685, train_accuracy: 0.9844, test_Accuracy: 0.9570
# Epoch: [ 0] [  447/  468] time: 123.9859, train_loss: 0.10575539, train_accuracy: 0.9609, test_Accuracy: 0.9568
# Epoch: [ 0] [  448/  468] time: 124.3507, train_loss: 0.28514296, train_accuracy: 0.9375, test_Accuracy: 0.9569
# Epoch: [ 0] [  449/  468] time: 124.7159, train_loss: 0.19312173, train_accuracy: 0.9609, test_Accuracy: 0.9571
# Epoch: [ 0] [  450/  468] time: 125.0914, train_loss: 0.09534451, train_accuracy: 0.9609, test_Accuracy: 0.9585
# Epoch: [ 0] [  451/  468] time: 125.4480, train_loss: 0.17191449, train_accuracy: 0.9688, test_Accuracy: 0.9582
# Epoch: [ 0] [  452/  468] time: 125.8282, train_loss: 0.12773804, train_accuracy: 0.9609, test_Accuracy: 0.9583
# Epoch: [ 0] [  453/  468] time: 126.0916, train_loss: 0.15245633, train_accuracy: 0.9453, test_Accuracy: 0.9593
# Epoch: [ 0] [  454/  468] time: 126.3203, train_loss: 0.09519149, train_accuracy: 0.9766, test_Accuracy: 0.9613
# Epoch: [ 0] [  455/  468] time: 126.5522, train_loss: 0.15742607, train_accuracy: 0.9609, test_Accuracy: 0.9615
# Epoch: [ 0] [  456/  468] time: 126.7904, train_loss: 0.15349184, train_accuracy: 0.9453, test_Accuracy: 0.9614
# Epoch: [ 0] [  457/  468] time: 127.0209, train_loss: 0.09221093, train_accuracy: 0.9766, test_Accuracy: 0.9599
# Epoch: [ 0] [  458/  468] time: 127.3695, train_loss: 0.08742426, train_accuracy: 0.9844, test_Accuracy: 0.9595
# Epoch: [ 0] [  459/  468] time: 127.5891, train_loss: 0.09442171, train_accuracy: 0.9688, test_Accuracy: 0.9590
# Epoch: [ 0] [  460/  468] time: 127.8311, train_loss: 0.27619690, train_accuracy: 0.9453, test_Accuracy: 0.9588
# Epoch: [ 0] [  461/  468] time: 128.0554, train_loss: 0.04601217, train_accuracy: 1.0000, test_Accuracy: 0.9583
# Epoch: [ 0] [  462/  468] time: 128.2911, train_loss: 0.10817540, train_accuracy: 0.9609, test_Accuracy: 0.9575
# Epoch: [ 0] [  463/  468] time: 128.5295, train_loss: 0.09445739, train_accuracy: 0.9688, test_Accuracy: 0.9579
# Epoch: [ 0] [  464/  468] time: 128.7614, train_loss: 0.12225887, train_accuracy: 0.9688, test_Accuracy: 0.9567
# Epoch: [ 0] [  465/  468] time: 128.9886, train_loss: 0.10323483, train_accuracy: 0.9688, test_Accuracy: 0.9569
# Epoch: [ 0] [  466/  468] time: 129.2319, train_loss: 0.07728156, train_accuracy: 1.0000, test_Accuracy: 0.9579
# Epoch: [ 0] [  467/  468] time: 129.5817, train_loss: 0.19278708, train_accuracy: 0.9453, test_Accuracy: 0.9584

# %% [markdown]
# **Relu test_Accuracy: 0.9584**
#
# **Softmax test_Accuracy: 0.9237**
