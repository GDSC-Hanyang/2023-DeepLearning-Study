# %%
import numpy as np
import tensorflow as tf

tf.random.set_seed(777)

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# adam optimizer : RMSProp + Momentum : Adaptive Learning rate + Momentum

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2153 - accuracy: 0.9372
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0967 - accuracy: 0.9707
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0684 - accuracy: 0.9782
# Epoch 4/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0547 - accuracy: 0.9823
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0421 - accuracy: 0.9863

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0690 - accuracy: 0.9796
# [0.06901136785745621, 0.9796000123023987]
